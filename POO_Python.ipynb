# %% [markdown]
# <a href="https://colab.research.google.com/github/andresromero14/POE-5-1/blob/gh-pages/POO_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class persona(): # clase persona
    def __init__(self,nombre,edad): # se inicializa con nombre y edad
        self.nombre=nombre
        self.edad=edad

# %%
andres=persona("Andres Romero", 21)

# %%
andres.nombre
andres.edad
# Out:
# 21
